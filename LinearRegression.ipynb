# %% [markdown]
# y= m * slope + intercept

# %% [markdown]
# ![FORMULA+FOR+b0+AND+b1+𝑏+1+=+𝑛+∑𝑥𝑦+−+∑𝑥+∑𝑦+𝑛+∑+𝑥+2+−+∑𝑥+2+Slope .jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image48.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# Intercept = ymean – slope* xmean

# %%
import numpy as np

# %%
X = np.array((1,2,3,4,5))
Y = np.array((1,2,3,4,5))

# %%
Xi = X 
Yi = Y
    
#Total number of data points:
n = len(Xi)
    

#X bar:
Xi_mean = Xi.mean()

#Y bar:
Yi_mean = Yi.mean()
    

#Sum of X:
S_Xi = (Xi).sum()
    

#Sum of Y:
S_Yi = (Yi).sum()
    

#Sum of (X*Y) multiplied by n:
S_XiYi = ((Xi*Yi).sum())*n
    
#Sum of X*Sum of Y:
S_Xi_S_Yi = S_Xi*S_Yi
    
#Sum of (X*X) multiplied by n:
S_XiXi = ((Xi*Xi).sum())*n
    
#Square of sum of X:
S_Xi_Square = S_Xi*S_Xi
    
#Slope:
dummy_slope = (S_XiYi- S_Xi_S_Yi) / (S_XiXi-S_Xi_Square)
    
#Intercept:
dummy_intercept = Yi_mean - dummy_slope * Xi_mean

# %%
#Check the function with dummy data:
y= (dummy_slope * X)  +  dummy_intercept
print ("Slope : " , dummy_slope)
print ("Intercept :",dummy_intercept)
# Out:
# Slope :  1.0
# Intercept : 0.0

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y)
plt.plot(X,y,color="red")
plt.show()

# %%
from statistics import mean
import numpy as np
x = np.array([1,2,3,4,5], dtype=np.float64)
y = np.array([5,4,6,5,6], dtype=np.float64)
def best_fit_slope(x,y ):
    m = (((mean(x)*mean(y)) - mean(x*y)) /
         ((mean(x)**2) - mean(x**2)))
    return m

m = best_fit_slope(x,y)
print(m)
# Out:
# 0.29999999999999893
