# %% [markdown]
# ![1*eeIvlwkMNG1wSmj3FR6M2g.gif](data:image/gif;base64,...)

# %% [markdown]
# ![1*Bt_rgkYCkx5YtcGxpR4M2A.gif](data:image/gif;base64,...)

# %% [markdown]
# ![sample-plot-residuals-1.png](data:image/png;base64,...)

# %% [markdown]
# ![2t3shpyn.6_(5)_(1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Y= mX+C

# %% [markdown]
# ![2022-01-03_19-09.png](data:image/png;base64,...)

# %% [markdown]
# X' -> Mean of X
# Y' -> Mean of Y

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5]) 
y = np.array([7,14,15,18,21])

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y
# Out:
# array([ 7, 14, 15, 18, 21])

# %%
n = np.size(x)

# %%
x_mean = np.mean(x)

# %%
y_mean = np.mean(y)

# %%
XMeanDiff = x-x_mean

# %%
XMeanDiff
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
YMeanDiff = y-y_mean

# %%
YMeanDiff
# Out:
# array([-8., -1.,  0.,  3.,  6.])

# %%
#(X-MeanX)*(Y-MeanY)
XMeanDiff*YMeanDiff
# Out:
# array([16.,  1.,  0.,  3., 12.])

# %%
sumDiff=sum(XMeanDiff*YMeanDiff)
sumDiff
# Out:
# 32.0

# %%
XDiffSQ= XMeanDiff *XMeanDiff

# %%
sumXDiffSQ = sum(XDiffSQ)

# %%
m=sumDiff/sumXDiffSQ

# %%
m
# Out:
# 3.2

# %%
c=y_mean-(x_mean*m)
c
# Out:
# 5.399999999999999

# %%
y1=(m*x)+c
y1
# Out:
# array([ 8.6, 11.8, 15. , 18.2, 21.4])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x,y1,color="red")
plt.show()

# %%
x = np.array([1,2,3,4,5]) 
y = np.array([7,14,15,18,21])

# %% [markdown]
# ![index.jpeg](data:image/jpeg;base64,...)

# %%
m = (((np.mean(x)*np.mean(y)) - np.mean(x*y)) / ((np.mean(x)**2) - np.mean(x**2)))

# %%
m
# Out:
# 3.1999999999999993
